# %% [markdown]
# ## Imports

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# The Piotroski Score is a financial scoring system used to evaluate the financial strength of a company based on its financial statements.
# The Piotroski Score is based on nine criteria, grouped into three main categories: profitability, leverage/liquidity, and operating efficiency. Here are the nine criteria:
#
# - **CR1** — net income for the current year; 1 if positive, else 0
# - **CR2** — return on assets (ROA) in the current year; 1 if positive, else 0
# - **CR3** — operating cash flow in the current year; 1 if positive, else 0
# - **CR4** — cash flow from operations being greater than net income; 1 if positive, else 0
# - **CR5** — decreased leverage compared with the previous year; 1 if negative (i.e., long-term debt has reduced), else 0
# - **CR6** — more liquidity compared with the previous year; 1 if positive, else 0
# - **CR7** — lack of dilution compared with the previous year; 1 if positive or 0 (no changes to shares), else 0
# - **CR8** — higher gross margin compared to the previous year; 1 if positive, else 0
# - **CR9** — higher asset turnover ratio compared to the previous year; 1 if positive, else 0
# - **Score** — summation of all the criteria

# %%
# Stock symbols
SYMBOLS = 'EREGL.IS,ISDMR.IS,KCAER.IS,CIMSA.IS,OYAKC.IS,BTCIM.IS,HEKTS.IS,GUBRF.IS,EGGUB.IS,ENJSA.IS,GWIND.IS,AKFYE.IS,AYDEM.IS,AKSEN.IS,ARCLK.IS,VESBE.IS,AKMGY.IS,OZKGY.IS,AKSGY.IS,EKGYO.IS,BIMAS.IS,MGROS.IS,SOKM.IS,THYAO.IS,PGSUS.IS,DESA.IS,PARSN.IS,TUPRS.IS,BOBET.IS,BRISA.IS'.split(',')
# Criteria + Score 
CRITERIA = 'CR1,CR2,CR3,CR4,CR5,CR6,CR7,CR8,CR9,Score'.split(',')

# Column Names
COLUMN_MAPPING_RAW={'Symbol': 'Symbol', 'Name': 'Name', 'CR1': 'Net Income', 'CR2': 'Return on Assets',
                'CR3': 'Op. Cash Flow', 'CR4': 'Quality of Earn', 'CR5': 'Long Term Debt',
                'CR6': 'Current Ratio', 'CR7': 'New Shares', 'CR8': 'Gross Margin', 'CR9': 'Asset TR'}

# Column names mapping for score data
COLUMN_MAPPING_SCORE = COLUMN_MAPPING_RAW | {'Score':'Score'}

# %%
def net_income(ticker):
    df = ticker.income_stmt
    return df.loc['Net Income'].iloc[0]

def roa(ticker):
    df = ticker.balance_sheet
    avg_assets = (df.loc['Total Assets'].iloc[0] + df.loc['Total Assets'].iloc[1])/2
    return round(net_income(ticker)/avg_assets, 2)

def ocf(ticker):
    """Calculate Operating Cash Flow using Free Cash Flow and Captial Expenditure.
    Take the absolute value for Captial Expenditure as yf returns as a negative number """
    df = ticker.cash_flow
    if 'Operating Cash Flow' in df.index:
        return df.loc['Operating Cash Flow'].iloc[0]
    else:
        return df.loc['Free Cash Flow'].iloc[0] + abs(df.loc['Capital Expenditure']).iloc[0]

def ltdebt(ticker):
    df = ticker.balance_sheet
    return (df.loc['Long Term Debt'].iloc[1] - df.loc['Long Term Debt'].iloc[0])

def current_ratio(ticker):
    df = ticker.balance_sheet
    current_ratio_current = df.loc['Total Assets'].iloc[0]/df.loc['Total Liabilities Net Minority Interest'].iloc[0]
    current_ratio_prev = df.loc['Total Assets'].iloc[1]/df.loc['Total Liabilities Net Minority Interest'].iloc[1]
    return round((current_ratio_current - current_ratio_prev), 2)

def new_shares(ticker):
    df = ticker.balance_sheet
    return (df.loc['Common Stock'].iloc[1] - df.loc['Common Stock'].iloc[0])

def gross_margin(ticker):
    df = ticker.income_stmt
    gross_margin_current = df.loc['Gross Profit'].iloc[0]/ df.loc['Total Revenue'].iloc[0]
    gross_margin_prev = df.loc['Gross Profit'].iloc[1]/ df.loc['Total Revenue'].iloc[1]
    return (gross_margin_current - gross_margin_prev)

def asset_turnover_ratio(ticker):
    df_bs = ticker.balance_sheet
    y0, y1, y2 = df_bs.loc['Total Assets'].iloc[0], df_bs.loc['Total Assets'].iloc[1], df_bs.loc['Total Assets'].iloc[2]
    avg_asset_y0 = (y0 + y1)/2
    avg_asset_y1 = (y1 + y2)/2
    
    df_is = ticker.income_stmt
    tot_rvn_y0 = df_is.loc['Total Revenue'].iloc[0]/avg_asset_y0
    tot_rvn_y1 = df_is.loc['Total Revenue'].iloc[1]/avg_asset_y1

    return round((tot_rvn_y0 - tot_rvn_y1), 2)

# %% [markdown]
# Store functions in a dictionary to call the relevant function in calculating the Piotroski score.

# %%
criteria_dict = {
    'CR1':net_income,
    'CR2':roa,
    'CR3':ocf,
    'CR5':ltdebt,
    'CR6':current_ratio,
    'CR7':new_shares,
    'CR8':gross_margin,
    'CR9':asset_turnover_ratio
}

# %%
def calculate_piotroski_score():
    #Loop through each symbol and retrieve ticker data using
    ps_criteria = {
        'Symbol':[],'Name':[],'CR1':[],'CR2':[],'CR3':[],'CR4':[],'CR5':[],
        'CR6':[],'CR7':[],'CR8':[],'CR9':[]
    }

    ps_criteria_data = {
        'Symbol':[],'Name':[],'CR1':[],'CR2':[],'CR3':[],'CR4':[],'CR5':[],
        'CR6':[],'CR7':[],'CR8':[],'CR9':[]
    }

    for symbol in SYMBOLS:
        ticker = yf.Ticker(symbol)


        ps_criteria['Symbol'].append(ticker.info['symbol'])
        ps_criteria['Name'].append(ticker.info['longName'])
        
        ps_criteria_data['Symbol'].append(ticker.info['symbol'])
        ps_criteria_data['Name'].append(ticker.info['longName'])

        #Loop through the dictionary containing criteria and their associated functions
        for key, value in criteria_dict.items():
            try:
                
                result = value(ticker)
                ps_criteria_data[key].append(result)
                #Special adjustment for CR7 - If the number of shares for the current year decreases or stays the same (0 is returned as the difference), a value of 1 is assigned.
                if key == 'CR7':
                    ps_criteria[key].append(1 if result >= 0 else 0)
                else:
                    #Process with other CRs
                    ps_criteria[key].append(1 if result > 0 else 0)
            except (KeyError, IndexError) as err:
                #Zero is assigned to the score and nan to raw data for any errors
                print(err)
                ps_criteria[key].append(0)
                ps_criteria_data[key].append(np.nan)

        #CR4 - Compute the score for CR4 using data for CR1 and CR3
        if ps_criteria_data['CR3'][-1] > ps_criteria_data['CR1'][-1]:
            ps_criteria['CR4'].append(1)
            ps_criteria_data['CR4'].append(1)
        else:
            #Set criteria and raw data to false (0)
            ps_criteria['CR4'].append(0)
            ps_criteria_data['CR4'].append(0)
    return ps_criteria, ps_criteria_data

# %% [markdown]
# Create DataFrames

# %%
ps_criteria, ps_criteria_data = calculate_piotroski_score()
ps_criteria_df = pd.DataFrame(ps_criteria)
# Add ranking scores to get the total score
ps_criteria_df['Score'] = ps_criteria_df[CRITERIA[:-1]].sum(axis=1)
ps_criteria_df
# Out:
# 'Long Term Debt'
# 'Long Term Debt'
# 'Long Term Debt'
#       Symbol                                               Name  CR1  CR2  \
# 0   EREGL.IS           Eregli Demir ve Çelik Fabrikalari T.A.S.    1    1
# 1   ISDMR.IS                     Iskenderun Demir ve Çelik A.S.    1    1
# 2   KCAER.IS      Kocaer Celik Sanayi ve Ticaret Anonim Sirketi    1    1
# 3   CIMSA.IS               Çimsa Çimento Sanayi ve Ticaret A.S.    1    1
# 4   OYAKC.IS                      OYAK Çimento Fabrikalari A.S.    1    1
# 5   BTCIM.IS  Batiçim Bati Anadolu Çimento Sanayii Anonim Si...    1    1
# 6   HEKTS.IS                              Hektas Ticaret T.A.S.    0    0
# 7   GUBRF.IS              Gübre Fabrikalari Türk Anonim Sirketi    0    0
# 8   EGGUB.IS                             Ege Gübre Sanayii A.S.    1    0
# 9   ENJSA.IS                               Enerjisa Enerji A.S.    1    1
# 10  GWIND.IS                            Galata Wind Enerji A.S.    1    1
# 11  AKFYE.IS                         Akfen Yenilenebilir Enerji    1    1
# 12  AYDEM.IS                    Aydem Yenilenebilir Enerji A.S.    0    0
# 13  AKSEN.IS                            Aksa Enerji Üretim A.S.    1    1
# 14  ARCLK.IS                             Arçelik Anonim Sirketi    1    1
# 15  VESBE.IS           Vestel Beyaz Esya Sanayi ve Ticaret A.S.    1    1
# 16  AKMGY.IS        Akmerkez Gayrimenkul Yatirim Ortakligi A.S.    1    1
# 17  OZKGY.IS            Ozak Gayrimenkul Yatirim Ortakligi A.S.    1    1
# 18  AKSGY.IS            Akis Gayrimenkul Yatirim Ortakligi A.S.    1    1
# 19  EKGYO.IS     Emlak Konut Gayrimenkul Yatirim Ortakligi A.S.    0    0
# 20  BIMAS.IS                        BIM Birlesik Magazalar A.S.    1    1
# 21  MGROS.IS                                Migros Ticaret A.S.    1    1
# 22   SOKM.IS                         Sok Marketler Ticaret A.S.    1    1
# 23  THYAO.IS                 Türk Hava Yollari Anonim Ortakligi    1    1
# 24  PGSUS.IS           Pegasus Hava Tasimaciligi Anonim Sirketi    1    1
# 25   DESA.IS                   Desa Deri Sanayi ve Ticaret A.S.    1    1
# 26  PARSN.IS               Parsan Makina Parçalari Sanayii A.S.    1    1
# 27  TUPRS.IS                   Türkiye Petrol Rafinerileri A.S.    1    1
# 28  BOBET.IS    Bogazici Beton Sanayi Ve Ticaret Anonim Sirketi    1    1
# 29  BRISA.IS  Brisa Bridgestone Sabanci Lastik Sanayi ve Tic...    1    1
#
#     CR3  CR4  CR5  CR6  CR7  CR8  CR9  Score
# 0     1    1    0    0    1    0    0      5
# 1     1    1    0    0    1    0    0      5
# 2     1    0    0    1    1    1    0      6
# 3     1    1    0    1    0    1    0      6
# 4     1    0    1    1    0    1    1      7
# 5     1    0    1    1    1    1    0      7
# 6     1    1    0    0    1    0    0      3
# 7     1    1    0    1    1    0    0      4
# 8     1    0    0    0    0    0    0      2
# 9     1    1    0    1    1    1    0      7
# 10    1    1    1    0    0    0    0      5
# 11    1    0    1    1    1    0    0      6
# 12    1    1    1    1    1    0    0      5
# 13    1    0    0    1    1    1    0      6
# 14    0    0    0    0    1    1    0      4
# 15    1    0    0    1    1    1    0      6
# 16    1    0    0    0    1    0    0      4
# 17    1    0    0    1    0    0    0      4
# 18    1    0    1    1    1    0    0      6
# 19    1    1    1    0    1    1    0      5
# 20    1    1    0    1    1    1    0      7
# 21    1    1    1    1    1    1    0      8
# 22    1    1    0    1    1    0    0      6
# 23    1    0    1    1    1    0    0      6
# 24    1    0    0    1    1    0    0      5
# 25    1    1    1    1    0    1    0      7
# 26    1    0    0    1    1    1    0      6
# 27    1    1    1    1    0    1    0      7
# 28    1    1    0    0    1    1    0      6
# 29    1    0    0    1    1    1    0      6

# %%
ps_criteria_data_df = pd.DataFrame(ps_criteria_data)
ps_criteria_data_df
# Out:
#       Symbol                                               Name           CR1  \
# 0   EREGL.IS           Eregli Demir ve Çelik Fabrikalari T.A.S.  4.033089e+09
# 1   ISDMR.IS                     Iskenderun Demir ve Çelik A.S.  4.601547e+09
# 2   KCAER.IS      Kocaer Celik Sanayi ve Ticaret Anonim Sirketi  1.186704e+09
# 3   CIMSA.IS               Çimsa Çimento Sanayi ve Ticaret A.S.  2.490891e+09
# 4   OYAKC.IS                      OYAK Çimento Fabrikalari A.S.  8.127896e+09
# 5   BTCIM.IS  Batiçim Bati Anadolu Çimento Sanayii Anonim Si...  1.833899e+09
# 6   HEKTS.IS                              Hektas Ticaret T.A.S. -8.782390e+08
# 7   GUBRF.IS              Gübre Fabrikalari Türk Anonim Sirketi -4.172754e+08
# 8   EGGUB.IS                             Ege Gübre Sanayii A.S.  1.001039e+09
# 9   ENJSA.IS                               Enerjisa Enerji A.S.  4.517326e+09
# 10  GWIND.IS                            Galata Wind Enerji A.S.  6.235477e+08
# 11  AKFYE.IS                         Akfen Yenilenebilir Enerji  4.553839e+09
# 12  AYDEM.IS                    Aydem Yenilenebilir Enerji A.S. -1.280101e+09
# 13  AKSEN.IS                            Aksa Enerji Üretim A.S.  5.496565e+09
# 14  ARCLK.IS                             Arçelik Anonim Sirketi  7.667336e+09
# 15  VESBE.IS           Vestel Beyaz Esya Sanayi ve Ticaret A.S.  4.724452e+09
# 16  AKMGY.IS        Akmerkez Gayrimenkul Yatirim Ortakligi A.S.  4.965474e+08
# 17  OZKGY.IS            Ozak Gayrimenkul Yatirim Ortakligi A.S.  2.941966e+09
# 18  AKSGY.IS            Akis Gayrimenkul Yatirim Ortakligi A.S.  3.358458e+09
# 19  EKGYO.IS     Emlak Konut Gayrimenkul Yatirim Ortakligi A.S. -4.074314e+09
# 20  BIMAS.IS                        BIM Birlesik Magazalar A.S.  1.544073e+10
# 21  MGROS.IS                                Migros Ticaret A.S.  8.828696e+09
# 22   SOKM.IS                         Sok Marketler Ticaret A.S.  4.446246e+09
# 23  THYAO.IS                 Türk Hava Yollari Anonim Ortakligi  5.519949e+09
# 24  PGSUS.IS           Pegasus Hava Tasimaciligi Anonim Sirketi  2.090750e+10
# 25   DESA.IS                   Desa Deri Sanayi ve Ticaret A.S.  4.960417e+08
# 26  PARSN.IS               Parsan Makina Parçalari Sanayii A.S.  3.651278e+08
# 27  TUPRS.IS                   Türkiye Petrol Rafinerileri A.S.  5.357734e+10
# 28  BOBET.IS    Bogazici Beton Sanayi Ve Ticaret Anonim Sirketi  1.404194e+09
# 29  BRISA.IS  Brisa Bridgestone Sabanci Lastik Sanayi ve Tic...  3.985644e+09
#
#      CR2           CR3  CR4           CR5   CR6           CR7       CR8   CR9
# 0   0.02  1.306814e+10    1 -2.486547e+09 -0.49  0.000000e+00 -0.103567 -0.24
# 1   0.04  1.382081e+10    1 -4.553800e+08 -0.53  0.000000e+00 -0.080867 -0.11
# 2   0.10  5.536528e+08    0 -3.296917e+08  0.50  0.000000e+00  0.019936 -1.04
# 3   0.07  2.836809e+09    1 -4.548940e+08  0.29 -8.105070e+08  0.082167 -0.05
# 4   0.23  7.232825e+09    0  5.208406e+07  1.98 -8.678496e+07  0.056705  0.04
# 5   0.10  6.251900e+08    0  5.250970e+08  0.73  0.000000e+00  0.057628 -0.42
# 6  -0.04  1.477970e+09    1 -6.858029e+08 -0.14  0.000000e+00 -0.167645 -0.47
# 7  -0.02  2.536379e+09    1           NaN  0.47  0.000000e+00 -0.041965 -0.15
# 8    NaN  4.719275e+08    0           NaN   NaN           NaN -0.044462   NaN
# 9   0.05  6.470128e+09    1 -9.140351e+09  0.20  0.000000e+00  0.009453 -1.84
# 10  0.07  1.979152e+09    1  1.107780e+08 -0.50 -5.208542e+06 -0.121155 -0.23
# 11  0.13  1.808221e+09    0  2.391703e+09  0.62  0.000000e+00 -0.077867 -0.08
# 12 -0.02  4.410757e+09    1  1.467894e+09  0.10  0.000000e+00 -0.121537 -0.07
# 13  0.12  4.722179e+09    0 -1.292270e+09  0.31  0.000000e+00  0.085777 -0.90
# 14  0.03 -8.641863e+09    0 -1.768043e+10 -0.03  0.000000e+00  0.026160 -0.57
# 15  0.12  3.907270e+09    0 -1.203114e+09  0.41  0.000000e+00  0.065976 -1.40
# 16  0.09  2.601952e+08    0           NaN -5.66  0.000000e+00 -0.023671 -0.03
# 17  0.10  1.152932e+09    0 -9.318257e+07  1.58 -7.280000e+08 -0.328476 -0.16
# 18  0.14  1.405308e+09    0  1.763190e+09  2.94  0.000000e+00 -0.078079 -0.00
# 19 -0.03  3.382991e+09    1  3.805121e+09 -0.15  0.000000e+00  0.057801 -0.04
# 20  0.11  2.003046e+10    1           NaN  0.03  0.000000e+00  0.006703 -1.17
# 21  0.10  1.397843e+10    1  1.451526e+09  0.14  0.000000e+00  0.000164 -0.73
# 22  0.09  1.315079e+10    1           NaN  0.07  0.000000e+00 -0.005650 -1.31
# 23  0.17  4.911378e+09    0  6.458229e+08  0.31  2.710066e+07 -0.006278 -0.06
# 24  0.14  2.017667e+10    0 -5.852991e+09  0.14  0.000000e+00 -0.032461 -0.10
# 25  0.20  5.882611e+08    1  5.181230e+07  0.79 -1.957780e+08  0.084195 -0.72
# 26  0.04  2.663592e+08    0 -4.622122e+08  0.35  0.000000e+00  0.011559 -0.06
# 27  0.15  8.527632e+10    1  2.968399e+10  0.17 -1.651539e+09  0.036488 -2.12
# 28  0.24  2.565693e+09    1 -1.921990e+08 -0.01  0.000000e+00  0.059675 -0.42
# 29  0.11  3.471724e+09    0 -3.048459e+09  0.02  0.000000e+00  0.023613 -0.49

# %%
def make_pretty_score(styler):
    # Columns with 0 decimal points
    zero_formats = {}
    for idx in range(1,10):
        zero_formats[f'CR{idx}']='{:.0f}'        
    styler.format(zero_formats)
    
    # Hide index
    styler.hide(axis='index')

    # Left text alignment for Symbol and Name columns
    styler.set_properties(subset=['Symbol', 'Name'], **{'text-align': 'left'})
    # Center alignment for the rest
    styler.set_properties(subset=CRITERIA, **{'text-align': 'center'})

    # Set background gradients
    styler.background_gradient(subset=['Score'], cmap='PiYG')
    
    # Borders
    styler.set_properties(**{'border': '1px solid grey'})
    return styler

def column_formatter_score(name):
    return COLUMN_MAPPING_SCORE[name]

# %%
# Add table caption and styles to DF
ps_criteria_df.style.pipe(make_pretty_score).set_caption(f'Piotroski Score').set_table_styles(
    [{'selector': 'th.col_heading', 'props': [('text-align', 'center'),
                                              ('color', 'bisque'), ('font-size', '10pt')]},
     {'selector': 'td', 'props': [('font-size', '10pt')]},
     {'selector': 'caption', 'props': [('text-align', 'center'), ('color', 'goldenrod'),
                                       ('font-size', '14pt'), ('font-weight', 'bold')]}]).format_index(column_formatter_score, axis=1)
# Out:
# <style type="text/css">
# #T_6887d th.col_heading {
#   text-align: center;
#   color: bisque;
#   font-size: 10pt;
# }
# #T_6887d td {
#   font-size: 10pt;
# }
# #T_6887d caption {
#   text-align: center;
#   color: goldenrod;
#   font-size: 14pt;
#   font-weight: bold;
# }
# #T_6887d_row0_col0, #T_6887d_row0_col1, #T_6887d_row1_col0, #T_6887d_row1_col1, #T_6887d_row2_col0, #T_6887d_row2_col1, #T_6887d_row3_col0, #T_6887d_row3_col1, #T_6887d_row4_col0, #T_6887d_row4_col1, #T_6887d_row5_col0, #T_6887d_row5_col1, #T_6887d_row6_col0, #T_6887d_row6_col1, #T_6887d_row7_col0, #T_6887d_row7_col1, #T_6887d_row8_col0, #T_6887d_row8_col1, #T_6887d_row9_col0, #T_6887d_row9_col1, #T_6887d_row10_col0, #T_6887d_row10_col1, #T_6887d_row11_col0, #T_6887d_row11_col1, #T_6887d_row12_col0, #T_6887d_row12_col1, #T_6887d_row13_col0, #T_6887d_row13_col1, #T_6887d_row14_col0, #T_6887d_row14_col1, #T_6887d_row15_col0, #T_6887d_row15_col1, #T_6887d_row16_col0, #T_6887d_row16_col1, #T_6887d_row17_col0, #T_6887d_row17_col1, #T_6887d_row18_col0, #T_6887d_row18_col1, #T_6887d_row19_col0, #T_6887d_row19_col1, #T_6887d_row20_col0, #T_6887d_row20_col1, #T_6887d_row21_col0, #T_6887d_row21_col1, #T_6887d_row22_col0, #T_6887d_row22_col1, #T_6887d_row23_col0, #T_6887d_row23_col1, #T_6887d_row24_col0, #T_6887d_row24_col1, #T_6887d_row25_col0, #T_6887d_row25_col1, #T_6887d_row26_col0, #T_6887d_row26_col1, #T_6887d_row27_col0, #T_6887d_row27_col1, #T_6887d_row28_col0, #T_6887d_row28_col1, #T_6887d_row29_col0, #T_6887d_row29_col1 {
#   text-align: left;
#   border: 1px solid grey;
# }
# #T_6887d_row0_col2, #T_6887d_row0_col3, #T_6887d_row0_col4, #T_6887d_row0_col5, #T_6887d_row0_col6, #T_6887d_row0_col7, #T_6887d_row0_col8, #T_6887d_row0_col9, #T_6887d_row0_col10, #T_6887d_row1_col2, #T_6887d_row1_col3, #T_6887d_row1_col4, #T_6887d_row1_col5, #T_6887d_row1_col6, #T_6887d_row1_col7, #T_6887d_row1_col8, #T_6887d_row1_col9, #T_6887d_row1_col10, #T_6887d_row2_col2, #T_6887d_row2_col3, #T_6887d_row2_col4, #T_6887d_row2_col5, #T_6887d_row2_col6, #T_6887d_row2_col7, #T_6887d_row2_col8, #T_6887d_row2_col9, #T_6887d_row2_col10, #T_6887d_row3_col2, #T_6887d_row3_col3, #T_6887d_row3_col4, #T_6887d_row3_col5, #T_6887d_row3_col6, #T_6887d_row3_col7, #T_6887d_row3_col8, #T_6887d_row3_col9, #T_6887d_row3_col10, #T_6887d_row4_col2, #T_6887d_row4_col3, #T_6887d_row4_col4, #T_6887d_row4_col5, #T_6887d_row4_col6, #T_6887d_row4_col7, #T_6887d_row4_col8, #T_6887d_row4_col9, #T_6887d_row4_col10, #T_6887d_row5_col2, #T_6887d_row5_col3, #T_6887d_row5_col4, #T_6887d_row5_col5, #T_6887d_row5_col6, #T_6887d_row5_col7, #T_6887d_row5_col8, #T_6887d_row5_col9, #T_6887d_row5_col10, #T_6887d_row6_col2, #T_6887d_row6_col3, #T_6887d_row6_col4, #T_6887d_row6_col5, #T_6887d_row6_col6, #T_6887d_row6_col7, #T_6887d_row6_col8, #T_6887d_row6_col9, #T_6887d_row6_col10, #T_6887d_row7_col2, #T_6887d_row7_col3, #T_6887d_row7_col4, #T_6887d_row7_col5, #T_6887d_row7_col6, #T_6887d_row7_col7, #T_6887d_row7_col8, #T_6887d_row7_col9, #T_6887d_row7_col10, #T_6887d_row8_col2, #T_6887d_row8_col3, #T_6887d_row8_col4, #T_6887d_row8_col5, #T_6887d_row8_col6, #T_6887d_row8_col7, #T_6887d_row8_col8, #T_6887d_row8_col9, #T_6887d_row8_col10, #T_6887d_row9_col2, #T_6887d_row9_col3, #T_6887d_row9_col4, #T_6887d_row9_col5, #T_6887d_row9_col6, #T_6887d_row9_col7, #T_6887d_row9_col8, #T_6887d_row9_col9, #T_6887d_row9_col10, #T_6887d_row10_col2, #T_6887d_row10_col3, #T_6887d_row10_col4, #T_6887d_row10_col5, #T_6887d_row10_col6, #T_6887d_row10_col7, #T_6887d_row10_col8, #T_6887d_row10_col9, #T_6887d_row10_col10, #T_6887d_row11_col2, #T_6887d_row11_col3, #T_6887d_row11_col4, #T_6887d_row11_col5, #T_6887d_row11_col6, #T_6887d_row11_col7, #T_6887d_row11_col8, #T_6887d_row11_col9, #T_6887d_row11_col10, #T_6887d_row12_col2, #T_6887d_row12_col3, #T_6887d_row12_col4, #T_6887d_row12_col5, #T_6887d_row12_col6, #T_6887d_row12_col7, #T_6887d_row12_col8, #T_6887d_row12_col9, #T_6887d_row12_col10, #T_6887d_row13_col2, #T_6887d_row13_col3, #T_6887d_row13_col4, #T_6887d_row13_col5, #T_6887d_row13_col6, #T_6887d_row13_col7, #T_6887d_row13_col8, #T_6887d_row13_col9, #T_6887d_row13_col10, #T_6887d_row14_col2, #T_6887d_row14_col3, #T_6887d_row14_col4, #T_6887d_row14_col5, #T_6887d_row14_col6, #T_6887d_row14_col7, #T_6887d_row14_col8, #T_6887d_row14_col9, #T_6887d_row14_col10, #T_6887d_row15_col2, #T_6887d_row15_col3, #T_6887d_row15_col4, #T_6887d_row15_col5, #T_6887d_row15_col6, #T_6887d_row15_col7, #T_6887d_row15_col8, #T_6887d_row15_col9, #T_6887d_row15_col10, #T_6887d_row16_col2, #T_6887d_row16_col3, #T_6887d_row16_col4, #T_6887d_row16_col5, #T_6887d_row16_col6, #T_6887d_row16_col7, #T_6887d_row16_col8, #T_6887d_row16_col9, #T_6887d_row16_col10, #T_6887d_row17_col2, #T_6887d_row17_col3, #T_6887d_row17_col4, #T_6887d_row17_col5, #T_6887d_row17_col6, #T_6887d_row17_col7, #T_6887d_row17_col8, #T_6887d_row17_col9, #T_6887d_row17_col10, #T_6887d_row18_col2, #T_6887d_row18_col3, #T_6887d_row18_col4, #T_6887d_row18_col5, #T_6887d_row18_col6, #T_6887d_row18_col7, #T_6887d_row18_col8, #T_6887d_row18_col9, #T_6887d_row18_col10, #T_6887d_row19_col2, #T_6887d_row19_col3, #T_6887d_row19_col4, #T_6887d_row19_col5, #T_6887d_row19_col6, #T_6887d_row19_col7, #T_6887d_row19_col8, #T_6887d_row19_col9, #T_6887d_row19_col10, #T_6887d_row20_col2, #T_6887d_row20_col3, #T_6887d_row20_col4, #T_6887d_row20_col5, #T_6887d_row20_col6, #T_6887d_row20_col7, #T_6887d_row20_col8, #T_6887d_row20_col9, #T_6887d_row20_col10, #T_6887d_row21_col2, #T_6887d_row21_col3, #T_6887d_row21_col4, #T_6887d_row21_col5, #T_6887d_row21_c ...
#   text-align: center;
#   border: 1px solid grey;
# }
# #T_6887d_row0_col11, #T_6887d_row1_col11, #T_6887d_row10_col11, #T_6887d_row12_col11, #T_6887d_row19_col11, #T_6887d_row24_col11 {
#   text-align: center;
#   background-color: #f7f7f6;
#   color: #000000;
#   border: 1px solid grey;
# }
# #T_6887d_row2_col11, #T_6887d_row3_col11, #T_6887d_row11_col11, #T_6887d_row13_col11, #T_6887d_row15_col11, #T_6887d_row18_col11, #T_6887d_row22_col11, #T_6887d_row23_col11, #T_6887d_row26_col11, #T_6887d_row28_col11, #T_6887d_row29_col11 {
#   text-align: center;
#   background-color: #c7e89f;
#   color: #000000;
#   border: 1px solid grey;
# }
# #T_6887d_row4_col11, #T_6887d_row5_col11, #T_6887d_row9_col11, #T_6887d_row20_col11, #T_6887d_row25_col11, #T_6887d_row27_col11 {
#   text-align: center;
#   background-color: #6dad36;
#   color: #f1f1f1;
#   border: 1px solid grey;
# }
# #T_6887d_
